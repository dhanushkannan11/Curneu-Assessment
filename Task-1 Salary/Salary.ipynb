# %% [markdown]
# # Problem Statement-1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
data_train = pd.read_csv("train.csv")
data_test = pd.read_csv("test.csv")

# %%
data_train.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data_train.shape
# Out:
# (32561, 15)

# %%
data_test.head()
# Out:
#    age   workclass  fnlwgt      education  education.num       marital.status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   18         NaN  103497   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital.gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                 NaN    Own-child   White   Female             0
#
#    capital.loss  hours.per.week  native.country   target
# ...

# %%
data_test.shape
# Out:
# (16281, 15)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  31978 non-null  object
#  14  target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data_train.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# target               0
# dtype: int64

# %%
data_train['target'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: target, dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder() 
data_train['target']= label_encoder.fit_transform(data_train['target'])

data_train.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  target
# 0          2174             0              40   United-States       0
# ...

# %%
data_train.tail()
# Out:
#        age      workclass  fnlwgt    education  education.num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital.status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital.gain  capital.loss  hours.per.week  native.country  target
# ...

# %%
data_train.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education.num   32561.0      10.080679       2.572720      1.0       9.0
# capital.gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital.loss    32561.0      87.303830     402.960219      0.0       0.0
# hours.per.week  32561.0      40.437456      12.347429      1.0      40.0
# target          32561.0       0.240810       0.427581      0.0       0.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education.num       10.0      12.0       16.0
# capital.gain         0.0       0.0    99999.0
# capital.loss         0.0       0.0     4356.0
# hours.per.week      40.0      45.0       99.0
# target               0.0       0.0        1.0

# %%
#column with zero values

zero_col = ['capital.gain','capital.loss']
for i in zero_col:
    data_train = data_train.drop(i,axis=1)

# %% [markdown]
# The columns with zero values are removed.

# %%
null_values = data_train.isnull().sum()
null_values = pd.DataFrame(null_values,columns=['null'])
j=1
sum_total=len(data_train)
null_values['percentage'] = null_values['null']/sum_total
round(null_values*100,3).sort_values('percentage',ascending=False)
# Out:
#                   null  percentage
# occupation      184300       5.660
# workclass       183600       5.639
# native.country   58300       1.790
# age                  0       0.000
# fnlwgt               0       0.000
# education            0       0.000
# education.num        0       0.000
# marital.status       0       0.000
# relationship         0       0.000
# race                 0       0.000
# sex                  0       0.000
# hours.per.week       0       0.000
# target               0       0.000

# %%
null_col = null_values.sort_values('percentage',ascending=False).index[:3]
null_col
# Out:
# Index(['occupation', 'workclass', 'native.country'], dtype='object')

# %%
data_train['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
data_train['occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
data_train['native.country'].value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
# ...

# %%
for col in null_col:
    data_train[col] = data_train[col].fillna(data_train[col].mode()[0])

# %% [markdown]
# Thus, null values are imputed with the mode of the attributes

# %%
data_train.shape
# Out:
# (32561, 13)

# %%
duplicates = data_train[data_train.duplicated()]
print("There are {} duplicate rows".format(duplicates.shape[0]))
# Out:
# There are 26 duplicate rows

# %%
data_train.drop_duplicates(keep="first",inplace=True)

# %%
data_train.shape
# Out:
# (32535, 13)

# %% [markdown]
# ## DATA VISUALIZATION

# %%
plt.figure(figsize=(18,8))
sns.heatmap(data_train.corr(),cmap="gnuplot",annot=True,linewidths=0.5)

# %%
plt.figure(figsize=(10,5))
sns.pairplot(data_train)

# %%
sns.countplot(x='target',data=data_train)

# %%
plt.figure(figsize=(25,8))
sns.countplot(x='occupation',data=data_train)

# %%
plt.figure(figsize=(25,8))
sns.countplot(x='occupation',data=data_train,hue='target',color='purple')

# %%
data_train.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'hours.per.week', 'native.country', 'target'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='age',data=data_train,hue='target')

# %% [markdown]
# The count of people at the ages of 30s who earns >50K is higher

# %%
plt.figure(figsize=(16,8))
sns.countplot(y="occupation", hue="target",data=data_train);

# %%
plt.figure(figsize=(16,8))
sns.violinplot(y="hours.per.week", x="marital.status",hue="sex", data=data_train,palette='Set1')

# %% [markdown]
# Performing EDA for test data:

# %%
data_test.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             16281.0      38.767459      13.849187     17.0      28.0
# fnlwgt          16281.0  189435.677784  105714.907671  13492.0  116736.0
# education.num   16281.0      10.072907       2.567545      1.0       9.0
# capital.gain    16281.0    1081.905104    7583.935968      0.0       0.0
# capital.loss    16281.0      87.899269     403.105286      0.0       0.0
# hours.per.week  16281.0      40.392236      12.479332      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          177831.0  238384.0  1490400.0
# education.num       10.0      12.0       16.0
# capital.gain         0.0       0.0    99999.0
# capital.loss         0.0       0.0     3770.0
# hours.per.week      40.0      45.0       99.0

# %%
def handle_missing_values(data_test):
    for col in null_col:
        data_test[col] = data_test[col].fillna(data_test[col].mode()[0])
        
def remove_duplicates(data_test):
    data_test.drop_duplicates(keep="first",inplace=True)

# %%
#remove_zero_attributes
zero_col = ['capital.gain','capital.loss']
for i in zero_col:
    data_test = data_test.drop(i,axis=1)

# %%
handle_missing_values(data_test)
remove_duplicates(data_test)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32535 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32535 non-null  int64
#  1   workclass       32535 non-null  object
#  2   fnlwgt          32535 non-null  int64
#  3   education       32535 non-null  object
#  4   education.num   32535 non-null  int64
#  5   marital.status  32535 non-null  object
#  6   occupation      32535 non-null  object
#  7   relationship    32535 non-null  object
#  8   race            32535 non-null  object
#  9   sex             32535 non-null  object
#  10  hours.per.week  32535 non-null  int64
#  11  native.country  32535 non-null  object
#  12  target          32535 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 4.4+ MB

# %%
labelled_attributes = ['workclass','education','marital.status','occupation','relationship','race','sex','native.country','target']

# %%
for i in labelled_attributes:
    for df in [data_train,data_test]:
        df[i] = label_encoder.fit_transform(df[i])

# %%
data_train.head(10)
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   39          6   77516          9             13               4
# 1   50          5   83311          9             13               2
# 2   38          3  215646         11              9               0
# 3   53          3  234721          1              7               2
# 4   28          3  338409          9             13               2
# 5   37          3  284582         12             14               2
# 6   49          3  160187          6              5               3
# 7   52          5  209642         11              9               2
# 8   31          3   45781         12             14               4
# 9   42          3  159449          9             13               2
#
#    occupation  relationship  race  sex  hours.per.week  native.country  target
# 0           0             1     4    1              40              38       0
# ...

# %% [markdown]
# ### MODEL FITTING FROM SCRATCH

# %%
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
X_train = data_train.drop(['target'], axis=1)
y_train = data_train['target']
X_test = data_test.drop(['target'], axis=1)
y_test = data_test['target']

# %%
col = X_train.columns
col
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'hours.per.week', 'native.country'],
#       dtype='object')

# %%
scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train, columns=[col])
X_test = pd.DataFrame(X_test, columns=[col])

X_train = np.asarray(X_train,dtype=np.float)
y_train = np.asarray(y_train,dtype=np.float)

# %%
#LOGISTIC REGRESSION
class logisticRegression:
    def __init__(self, lr=0.01, num_iter=1000, fit_intercept=True, verbose=False):
        self.lr = lr
        self.num_iter = num_iter
        self.fit_intercept = fit_intercept
        self.verbose = verbose
    
    def __add_intercept(self, X):
        intercept = np.ones((X.shape[0], 1))
        return np.concatenate((intercept, X), axis=1)
    
    def __sigmoid(self, z):
        return 1 / (1 + np.exp(-z))
    
    #defining loss function
    def __loss(self, h, y):
        return (-y * np.log(h) - (1 - y) * np.log(1 - h)).mean()
    
    def fit(self, X, y):
        if self.fit_intercept:
            X = self.__add_intercept(X)
        
        # weights initialization for gradient descent
        self.theta = np.zeros(X.shape[1])
        
        for i in range(self.num_iter):
            z = np.dot(X, self.theta)
            h = self.__sigmoid(z)
            gradient = np.dot(X.T, (h - y)) / y.size
            self.theta -= self.lr * gradient
            
            z = np.dot(X, self.theta)
            h = self.__sigmoid(z)
            loss = self.__loss(h, y)
    
    def predict_prob(self, X):
        if self.fit_intercept:
            X = self.__add_intercept(X)
    
        return self.__sigmoid(np.dot(X, self.theta))
    
    def predict(self, X, threshold=0.5):
        return self.predict_prob(X) >= threshold

# %%
model = logisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88     12430
#            1       0.63      0.39      0.48      3846
#
#     accuracy                           0.80     16276
#    macro avg       0.73      0.66      0.68     16276
# weighted avg       0.78      0.80      0.78     16276

# %%
metric = accuracy_score(y_test, y_pred)
print("Accuracy = {:0.2f}%".format(metric*100))
# Out:
# Accuracy = 80.26%

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(confusion_matrix(y_test, y_pred),annot=True,fmt='d')

# %% [markdown]
# ## LOGISTIC REGRESSION USING SKLEARN

# %%
from sklearn.linear_model import LogisticRegression

model2 = LogisticRegression()

# %%
model2.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
preds = model2.predict(X_test)

# %%
print(classification_report(y_test, preds))
metric = accuracy_score(y_test, y_pred)
print("Accuracy = {:0.2f}%".format(metric*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88     12430
#            1       0.63      0.39      0.48      3846
#
#     accuracy                           0.80     16276
#    macro avg       0.73      0.66      0.68     16276
# weighted avg       0.78      0.80      0.78     16276
#
# Accuracy = 80.26%

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(confusion_matrix(y_test, y_pred),annot=True,fmt='d')

# %% [markdown]
# ## Thus, the model from scratch and the model from sklearn provides the same accuracy of 80%
